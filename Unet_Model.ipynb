# %%
# Get Dataset
# !git clone https://github.com/ayamohamdd/IP-25.git
# Out:
# Cloning into 'IP-25'...
# remote: Enumerating objects: 709, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 709 (delta 0), reused 0 (delta 0), pack-reused 703 (from 2)
# Receiving objects: 100% (709/709), 403.03 MiB | 14.82 MiB/s, done.
# Updating files: 100% (691/691), done.

# %%
import tensorflow as tf
import tensorflow.keras.backend as K
from tensorflow.keras.layers import Conv2D, BatchNormalization, MaxPool2D, Input, Conv2DTranspose, Concatenate, Activation, Dropout
import os
import numpy as np
import matplotlib.pyplot as plt




input_size = (544, 960, 3)
num_of_classes = 8

# Color to Class mapping
COLOR_MAPPING = {
    (0, 0, 0): 0,        # Background clutter
    (128, 0, 0): 1,      # Building
    (128, 64, 128): 2,   # Road
    (0, 128, 0): 3,      # Tree
    (128, 128, 0): 4,    # Low vegetation
    (64, 0, 128): 5,     # Moving car
    (192, 0, 192): 6,    # Static car
    (64, 64, 0): 7       # Human
}

CLASS_TO_COLOR = {v: k for k, v in COLOR_MAPPING.items()}


# Modified rgb_to_class function
def rgb_to_class(mask):
    height, width = mask.shape[0], mask.shape[1]
    mask_classes = np.zeros((height, width), dtype=np.int32)

    for color, class_idx in COLOR_MAPPING.items():
        # Create boolean mask for current color
        color_mask = np.all(mask == color, axis=-1)
        mask_classes[color_mask] = class_idx

    return mask_classes

# Modified load_and_preprocess_image function
def load_and_preprocess_image(image_path, mask_path):
    # Load and preprocess image
    image = tf.io.read_file(image_path)
    image = tf.image.decode_jpeg(image)
    image = tf.cast(image, tf.float32)
    image = tf.image.resize(image, [input_size[0], input_size[1]])
    image = image / 255.0

    # Load and preprocess mask
    mask = tf.io.read_file(mask_path)
    mask = tf.image.decode_png(mask, channels=3)
    mask = tf.image.resize(mask, [input_size[0], input_size[1]], method='nearest')
    mask = tf.numpy_function(rgb_to_class, [mask], tf.int32)
    mask.set_shape([input_size[0], input_size[1]])

    return image, mask

# Rest of the model architecture and training code remains the same
def double_conv_block(inputs, num_filters, dropout_rate=0.1):
    x = Conv2D(num_filters, 3, padding="same", kernel_initializer='he_normal')(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(num_filters, 3, padding="same", kernel_initializer='he_normal')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    if dropout_rate > 0:
        x = Dropout(dropout_rate)(x)

    return x

def conv_block(inputs, num_filters, dropout_rate=0.1):
    x = Conv2D(num_filters, 3, padding="same", kernel_initializer="he_normal")(inputs)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(num_filters, 3, padding="same", kernel_initializer="he_normal")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    if dropout_rate > 0:
        x = Dropout(dropout_rate)(x)

    return x

def encoder_block(inputs, num_filters):
    x = double_conv_block(inputs, num_filters)
    p = MaxPool2D((2, 2), padding='same')(x)
    return x, p

def decoder_block(inputs, skip, num_filters):
    x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(inputs)
    x = Concatenate()([x, skip])
    x = double_conv_block(x, num_filters)
    return x

def build_unet(input_shape):
    inputs = Input(input_shape)
    s1, p1 = encoder_block(inputs, 32)
    s2, p2 = encoder_block(p1, 64)
    s3, p3 = encoder_block(p2, 128)
    s4, p4 = encoder_block(p3, 256)

    b1 = double_conv_block(p4, 512)

    d1 = decoder_block(b1, s4, 256)
    d2 = decoder_block(d1, s3, 128)
    d3 = decoder_block(d2, s2, 64)
    d4 = decoder_block(d3, s1, 32)

    outputs = Conv2D(num_of_classes, 1, padding="same", activation="softmax")(d4)
    return tf.keras.models.Model(inputs, outputs, name="UNET")

# Metrics functions remain the same
def dice_coefficient(y_true, y_pred):
    y_pred = K.argmax(y_pred, axis=-1)
    y_true = K.cast(y_true, tf.int32)
    y_pred = K.cast(y_pred, tf.int32)
    intersection = K.sum(K.cast(y_true == y_pred, tf.float32))
    return 2 * intersection / (K.sum(K.cast(y_true, tf.float32)) + K.sum(K.cast(y_pred, tf.float32)))

def precision(y_true, y_pred):
    y_pred = K.argmax(y_pred, axis=-1)
    true_positive = K.sum(K.cast((y_true == 1) & (y_pred == 1), tf.float32))
    false_positive = K.sum(K.cast((y_true == 0) & (y_pred == 1), tf.float32))
    return true_positive / (true_positive + false_positive + K.epsilon())

def recall(y_true, y_pred):
    y_pred = K.argmax(y_pred, axis=-1)
    true_positive = K.sum(K.cast((y_true == 1) & (y_pred == 1), tf.float32))
    false_negative = K.sum(K.cast((y_true == 1) & (y_pred == 0), tf.float32))
    return true_positive / (true_positive + false_negative + K.epsilon())

def jaccard_index(y_true, y_pred):
    y_pred = K.argmax(y_pred, axis=-1)
    y_true = K.cast(y_true, tf.int32)
    y_pred = K.cast(y_pred, tf.int32)
    intersection = K.sum(K.cast(y_true == y_pred, tf.float32))
    union = K.sum(K.cast(y_true, tf.float32)) + K.sum(K.cast(y_pred, tf.float32)) - intersection
    return intersection / (union + K.epsilon())

def pixel_accuracy(y_true, y_pred):
    y_pred = K.argmax(y_pred, axis=-1)
    y_true = K.cast(y_true, tf.int32)
    y_pred = K.cast(y_pred, tf.int32)
    correct_pixels = K.sum(K.cast(y_true == y_pred, tf.float32))
    total_pixels = tf.cast(tf.size(y_true), tf.float32)
    return correct_pixels / total_pixels

# Build and compile model
unet = build_unet(input_size)
unet.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss='sparse_categorical_crossentropy',
    metrics=[pixel_accuracy, dice_coefficient, precision, recall, jaccard_index]
)

# Dataset paths
train_image_path = '/content/IP-25/train_data/Images'
train_mask_path = '/content/IP-25/train_data/Labels'
val_image_path = '/content/IP-25/val_data/Images'
val_mask_path = '/content/IP-25/val_data/Labels'

train_image_list = sorted([os.path.join(train_image_path, i) for i in os.listdir(train_image_path)])
train_mask_list = sorted([os.path.join(train_mask_path, i) for i in os.listdir(train_mask_path)])
val_image_list = sorted([os.path.join(val_image_path, i) for i in os.listdir(val_image_path)])
val_mask_list = sorted([os.path.join(val_mask_path, i) for i in os.listdir(val_mask_path)])

# Data generator
def data_generator(image_list, mask_list, batch_size):
    num_samples = len(image_list)
    while True:
        indices = np.random.permutation(num_samples)
        for i in range(0, num_samples, batch_size):
            batch_indices = indices[i:i + batch_size]
            batch_images = []
            batch_masks = []

            for idx in batch_indices:
                image, mask, = load_and_preprocess_image(image_list[idx], mask_list[idx])
                batch_images.append(image)
                batch_masks.append(mask)

            yield np.array(batch_images), np.array(batch_masks)

# Training setup
batch_size = 8
train_steps_per_epoch = len(train_image_list) // batch_size
val_steps_per_epoch = len(val_image_list) // batch_size

# Callbacks
callbacks = [
    tf.keras.callbacks.ModelCheckpoint('best_model2.keras', save_best_only=True, monitor='val_loss'),
    tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True),
    tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)
]

history = unet.fit(
    data_generator(train_image_list, train_mask_list, batch_size),
    steps_per_epoch=train_steps_per_epoch,
    epochs=20,
    validation_data=data_generator(val_image_list, val_mask_list, batch_size),
    validation_steps=val_steps_per_epoch,
    callbacks=callbacks
)
# Out:
# Epoch 1/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 189s 3s/step - dice_coefficient: 0.1434 - jaccard_index: 0.0794 - loss: 1.9312 - pixel_accuracy: 0.3096 - precision: 0.6156 - recall: 0.6745 - val_dice_coefficient: 0.2214 - val_jaccard_index: 0.1262 - val_loss: 28.5894 - val_pixel_accuracy: 0.3139 - val_precision: 0.5908 - val_recall: 0.9960 - learning_rate: 0.0010
# Epoch 2/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 98s 4s/step - dice_coefficient: 0.3046 - jaccard_index: 0.1804 - loss: 1.3073 - pixel_accuracy: 0.5529 - precision: 0.6774 - recall: 0.9130 - val_dice_coefficient: 0.0480 - val_jaccard_index: 0.0246 - val_loss: 471.3930 - val_pixel_accuracy: 0.0888 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 3/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - dice_coefficient: 0.3557 - jaccard_index: 0.2170 - loss: 1.1440 - pixel_accuracy: 0.6004 - precision: 0.7431 - recall: 0.8317 - val_dice_coefficient: 0.0609 - val_jaccard_index: 0.0314 - val_loss: 89.6942 - val_pixel_accuracy: 0.1128 - val_precision: 0.6411 - val_recall: 0.8788 - learning_rate: 0.0010
# Epoch 4/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 73s 3s/step - dice_coefficient: 0.3755 - jaccard_index: 0.2322 - loss: 1.0282 - pixel_accuracy: 0.6387 - precision: 0.7999 - recall: 0.8483 - val_dice_coefficient: 0.0587 - val_jaccard_index: 0.0303 - val_loss: 25.8839 - val_pixel_accuracy: 0.1116 - val_precision: 0.2275 - val_recall: 0.0173 - learning_rate: 0.0010
# Epoch 5/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - dice_coefficient: 0.3714 - jaccard_index: 0.2284 - loss: 0.9757 - pixel_accuracy: 0.6457 - precision: 0.7954 - recall: 0.8356 - val_dice_coefficient: 0.0598 - val_jaccard_index: 0.0309 - val_loss: 15.6619 - val_pixel_accuracy: 0.1107 - val_precision: 0.8841 - val_recall: 0.4077 - learning_rate: 0.0010
# Epoch 6/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 77s 3s/step - dice_coefficient: 0.3926 - jaccard_index: 0.2450 - loss: 0.9233 - pixel_accuracy: 0.6658 - precision: 0.8119 - recall: 0.8589 - val_dice_coefficient: 0.0532 - val_jaccard_index: 0.0273 - val_loss: 14.3030 - val_pixel_accuracy: 0.1005 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 7/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 77s 3s/step - dice_coefficient: 0.3903 - jaccard_index: 0.2431 - loss: 0.9279 - pixel_accuracy: 0.6528 - precision: 0.8232 - recall: 0.8562 - val_dice_coefficient: 0.1934 - val_jaccard_index: 0.1073 - val_loss: 2.1170 - val_pixel_accuracy: 0.3475 - val_precision: 0.6782 - val_recall: 0.6588 - learning_rate: 0.0010
# Epoch 8/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 75s 3s/step - dice_coefficient: 0.4117 - jaccard_index: 0.2601 - loss: 0.8549 - pixel_accuracy: 0.6844 - precision: 0.8342 - recall: 0.8546 - val_dice_coefficient: 0.1884 - val_jaccard_index: 0.1041 - val_loss: 2.1669 - val_pixel_accuracy: 0.2976 - val_precision: 0.8498 - val_recall: 0.1367 - learning_rate: 0.0010
# Epoch 9/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - dice_coefficient: 0.4021 - jaccard_index: 0.2520 - loss: 0.8227 - pixel_accuracy: 0.6925 - precision: 0.8344 - recall: 0.8877 - val_dice_coefficient: 0.2727 - val_jaccard_index: 0.1579 - val_loss: 1.5530 - val_pixel_accuracy: 0.4211 - val_precision: 0.8382 - val_recall: 0.3604 - learning_rate: 0.0010
# Epoch 10/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 76s 3s/step - dice_coefficient: 0.4194 - jaccard_index: 0.2659 - loss: 0.7773 - pixel_accuracy: 0.7103 - precision: 0.8480 - recall: 0.8831 - val_dice_coefficient: 0.1542 - val_jaccard_index: 0.0837 - val_loss: 2.4565 - val_pixel_accuracy: 0.2896 - val_precision: 0.9904 - val_recall: 0.0263 - learning_rate: 0.0010
# Epoch 11/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - dice_coefficient: 0.4009 - jaccard_index: 0.2514 - loss: 0.7729 - pixel_accuracy: 0.7097 - precision: 0.8435 - recall: 0.8983 - val_dice_coefficient: 0.1467 - val_jaccard_index: 0.0793 - val_loss: 2.3896 - val_pixel_accuracy: 0.2942 - val_precision: 0.9668 - val_recall: 0.0252 - learning_rate: 0.0010
# Epoch 12/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - dice_coefficient: 0.4177 - jaccard_index: 0.2647 - loss: 0.7594 - pixel_accuracy: 0.7153 - precision: 0.8453 - recall: 0.8998 - val_dice_coefficient: 0.2622 - val_jaccard_index: 0.1510 - val_loss: 1.6621 - val_pixel_accuracy: 0.4531 - val_precision: 0.9430 - val_recall: 0.3258 - learning_rate: 0.0010
# Epoch 13/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - dice_coefficient: 0.4161 - jaccard_index: 0.2634 - loss: 0.7709 - pixel_accuracy: 0.7103 - precision: 0.8614 - recall: 0.8967 - val_dice_coefficient: 0.2501 - val_jaccard_index: 0.1430 - val_loss: 1.7397 - val_pixel_accuracy: 0.3953 - val_precision: 0.9926 - val_recall: 0.0731 - learning_rate: 0.0010
# Epoch 14/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 77s 3s/step - dice_coefficient: 0.4274 - jaccard_index: 0.2723 - loss: 0.7031 - pixel_accuracy: 0.7361 - precision: 0.8820 - recall: 0.8921 - val_dice_coefficient: 0.2346 - val_jaccard_index: 0.1329 - val_loss: 2.0323 - val_pixel_accuracy: 0.3812 - val_precision: 0.9813 - val_recall: 0.0883 - learning_rate: 0.0010
# Epoch 15/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - dice_coefficient: 0.4240 - jaccard_index: 0.2694 - loss: 0.6590 - pixel_accuracy: 0.7518 - precision: 0.8615 - recall: 0.9277 - val_dice_coefficient: 0.2893 - val_jaccard_index: 0.1693 - val_loss: 1.4283 - val_pixel_accuracy: 0.4520 - val_precision: 0.9533 - val_recall: 0.2168 - learning_rate: 5.0000e-04
# Epoch 16/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 77s 3s/step - dice_coefficient: 0.4506 - jaccard_index: 0.2922 - loss: 0.6534 - pixel_accuracy: 0.7549 - precision: 0.8801 - recall: 0.9222 - val_dice_coefficient: 0.2931 - val_jaccard_index: 0.1718 - val_loss: 1.3067 - val_pixel_accuracy: 0.4965 - val_precision: 0.9608 - val_recall: 0.4505 - learning_rate: 5.0000e-04
# Epoch 17/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 77s 3s/step - dice_coefficient: 0.4420 - jaccard_index: 0.2843 - loss: 0.6102 - pixel_accuracy: 0.7724 - precision: 0.8873 - recall: 0.9358 - val_dice_coefficient: 0.3074 - val_jaccard_index: 0.1821 - val_loss: 1.2474 - val_pixel_accuracy: 0.5066 - val_precision: 0.9688 - val_recall: 0.4985 - learning_rate: 5.0000e-04
# Epoch 18/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 77s 3s/step - dice_coefficient: 0.4421 - jaccard_index: 0.2843 - loss: 0.6155 - pixel_accuracy: 0.7705 - precision: 0.9091 - recall: 0.9133 - val_dice_coefficient: 0.3307 - val_jaccard_index: 0.1984 - val_loss: 1.2036 - val_pixel_accuracy: 0.5282 - val_precision: 0.9804 - val_recall: 0.3113 - learning_rate: 5.0000e-04
# Epoch 19/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 77s 3s/step - dice_coefficient: 0.4300 - jaccard_index: 0.2744 - loss: 0.6220 - pixel_accuracy: 0.7672 - precision: 0.9010 - recall: 0.9083 - val_dice_coefficient: 0.3676 - val_jaccard_index: 0.2255 - val_loss: 1.1236 - val_pixel_accuracy: 0.5768 - val_precision: 0.9786 - val_recall: 0.4393 - learning_rate: 5.0000e-04
# Epoch 20/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 77s 3s/step - dice_coefficient: 0.4461 - jaccard_index: 0.2876 - loss: 0.6078 - pixel_accuracy: 0.7712 - precision: 0.8973 - recall: 0.9374 - val_dice_coefficient: 0.3627 - val_jaccard_index: 0.2218 - val_loss: 0.9117 - val_pixel_accuracy: 0.6412 - val_precision: 0.9565 - val_recall: 0.6802 - learning_rate: 5.0000e-04

# %%
unet.save("unet.keras")

# %%
import os
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# Define color mapping for visualization
COLOR_MAPPING = {
    0: (0, 0, 0),           # Background clutter
    1: (128, 0, 0),         # Building
    2: (128, 64, 128),      # Road
    3: (0, 128, 0),         # Tree
    4: (128, 128, 0),       # Low vegetation
    5: (64, 0, 128),        # Moving car
    6: (192, 0, 192),       # Static car
    7: (64, 64, 0),         # Human
}

def class_to_rgb(predicted_mask):
    """
    Convert class indices to RGB colors based on the defined color mapping.

    Args:
        predicted_mask (np.ndarray): 2D array of class indices.

    Returns:
        np.ndarray: 3D array of RGB colors.
    """
    colorized_image = np.zeros((predicted_mask.shape[0], predicted_mask.shape[1], 3), dtype=np.uint8)
    for class_idx, color in COLOR_MAPPING.items():
        colorized_image[predicted_mask == class_idx] = color
    return colorized_image

def predict_and_visualize(image_path, mask_path, model, save_path=None):
    """
    Predict the segmentation mask for a single image and visualize the result.

    Args:
        image_path (str): Path to the input image.
        model (tf.keras.Model): Trained U-Net model.
        save_path (str, optional): Path to save the visualization. If None, it only displays the result.

    Returns:
        None
    """
    # Load and preprocess the image
    image = tf.io.read_file(image_path)
    image = tf.image.decode_jpeg(image)
    image = tf.image.resize(image, [input_size[0], input_size[1]])
    image = tf.clip_by_value(image / 255.0, 0, 1)
    input_image = tf.expand_dims(image, axis=0)  # Add batch dimension

    # Load and preprocess the true mask
    mask = tf.io.read_file(mask_path)
    mask = tf.image.decode_jpeg(mask)
    mask = tf.image.resize(mask, [input_size[0], input_size[1]], method='nearest')

    # Predict mask
    predicted_mask = tf.argmax(model.predict(input_image), axis=-1)
    predicted_mask = tf.squeeze(predicted_mask)  # Remove batch dimension

    # Convert class mask to RGB mask
    visual_mask = class_to_rgb(predicted_mask.numpy())  # Convert to numpy for visualization


    # Plot the original image and the predicted mask
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 3, 1)
    plt.title("Original Image")
    plt.imshow(image)
    plt.axis('off')

    plt.subplot(1, 3, 2)
    plt.title("Predicted Mask")
    plt.imshow(visual_mask)
    plt.axis('off')

    # Plot the ground truth label image
    plt.subplot(1, 3, 3)
    plt.title("Ground Truth Label")
    plt.imshow(mask, cmap='tab20')  # Using a colormap for visualization
    plt.axis('off')

    # Save or display the visualization
    if save_path:
        # Ensure the directory exists
        save_dir = os.path.dirname(save_path)
        if not os.path.exists(save_dir):
            os.makedirs(save_dir)
        plt.savefig(save_path)
        print(f"Visualization saved to: {save_path}")
    else:
        plt.show()

# %%
from tensorflow.keras.models import load_model
model_path = "/content/drive/MyDrive/IP project/unet.keras"  # Path to the saved model
# model_temp = load_model(model_path)

# %%
# Example usage
image_path = '/content/IP-25/val_data/Images/seq36_000600.png'  # Replace with your image path
mask_path = '/content/IP-25/val_data/Labels/seq36_000600.png'  # Replace with your mask path
save_path = '/content/predictions/prediction.png'                 # Specify a valid save directory
predict_and_visualize(image_path,mask_path, unet, save_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step
# Visualization saved to: /content/predictions/prediction.png
