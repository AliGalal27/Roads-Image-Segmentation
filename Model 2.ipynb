# %%
# !git clone https://github.com/ayamohamdd/IP-25.git
# Out:
# fatal: destination path 'IP-25' already exists and is not an empty directory.

# %%
import tensorflow as tf
import tensorflow.keras.backend as K
from tensorflow.keras.layers import Conv2D, BatchNormalization, MaxPool2D, Input, Conv2DTranspose, Concatenate, Activation, Dropout
import os
import numpy as np
import matplotlib.pyplot as plt

# Input size and number of classes remain the same
input_size = (544, 960, 3)
num_of_classes = 8

# Color mapping remains the same
COLOR_MAPPING = {
    (0, 0, 0): 0,        # Background clutter
    (128, 0, 0): 1,      # Building
    (128, 64, 128): 2,   # Road
    (0, 128, 0): 3,      # Tree
    (128, 128, 0): 4,    # Low vegetation
    (64, 0, 128): 5,     # Moving car
    (192, 0, 192): 6,    # Static car
    (64, 64, 0): 7       # Human
}

CLASS_TO_COLOR = {v: k for k, v in COLOR_MAPPING.items()}

# Modified rgb_to_class function
def rgb_to_class(mask):
    height, width = mask.shape[0], mask.shape[1]
    mask_classes = np.zeros((height, width), dtype=np.int32)

    for color, class_idx in COLOR_MAPPING.items():
        # Create boolean mask for current color
        color_mask = np.all(mask == color, axis=-1)
        mask_classes[color_mask] = class_idx

    return mask_classes

# Modified load_and_preprocess_image function
def load_and_preprocess_image(image_path, mask_path):
    # Load and preprocess image
    image = tf.io.read_file(image_path)
    image = tf.image.decode_jpeg(image)
    image = tf.cast(image, tf.float32)
    image = tf.image.resize(image, [input_size[0], input_size[1]])
    image = image / 255.0

    # Load and preprocess mask
    mask = tf.io.read_file(mask_path)
    mask = tf.image.decode_png(mask, channels=3)
    mask = tf.image.resize(mask, [input_size[0], input_size[1]], method='nearest')
    mask = tf.numpy_function(rgb_to_class, [mask], tf.int32)
    mask.set_shape([input_size[0], input_size[1]])

    return image, mask

# Rest of the model architecture and training code remains the same
def double_conv_block(inputs, num_filters, dropout_rate=0.1):
    x = Conv2D(num_filters, 3, padding="same", kernel_initializer='he_normal')(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(num_filters, 3, padding="same", kernel_initializer='he_normal')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    if dropout_rate > 0:
        x = Dropout(dropout_rate)(x)

    return x
def conv_block(inputs, num_filters, dropout_rate=0.1):
    x = Conv2D(num_filters, 3, padding="same", kernel_initializer="he_normal")(inputs)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(num_filters, 3, padding="same", kernel_initializer="he_normal")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    if dropout_rate > 0:
        x = Dropout(dropout_rate)(x)

    return x
def encoder_block(inputs, num_filters):
    x = double_conv_block(inputs, num_filters)
    p = MaxPool2D((2, 2), padding='same')(x)
    return x, p

def decoder_block(inputs, skip, num_filters):
    x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(inputs)
    x = Concatenate()([x, skip])
    x = double_conv_block(x, num_filters)
    return x

def build_unet(input_shape):
    inputs = Input(input_shape)
    s1, p1 = encoder_block(inputs, 32)
    s2, p2 = encoder_block(p1, 64)
    s3, p3 = encoder_block(p2, 128)
    s4, p4 = encoder_block(p3, 256)

    b1 = double_conv_block(p4, 512)

    d1 = decoder_block(b1, s4, 256)
    d2 = decoder_block(d1, s3, 128)
    d3 = decoder_block(d2, s2, 64)
    d4 = decoder_block(d3, s1, 32)

    outputs = Conv2D(num_of_classes, 1, padding="same", activation="softmax")(d4)
    return tf.keras.models.Model(inputs, outputs, name="UNET")

# Metrics functions remain the same
def dice_coefficient(y_true, y_pred):
    y_pred = K.argmax(y_pred, axis=-1)
    y_true = K.cast(y_true, tf.int32)
    y_pred = K.cast(y_pred, tf.int32)
    intersection = K.sum(K.cast(y_true == y_pred, tf.float32))
    return 2 * intersection / (K.sum(K.cast(y_true, tf.float32)) + K.sum(K.cast(y_pred, tf.float32)))

def precision(y_true, y_pred):
    y_pred = K.argmax(y_pred, axis=-1)
    true_positive = K.sum(K.cast((y_true == 1) & (y_pred == 1), tf.float32))
    false_positive = K.sum(K.cast((y_true == 0) & (y_pred == 1), tf.float32))
    return true_positive / (true_positive + false_positive + K.epsilon())

def recall(y_true, y_pred):
    y_pred = K.argmax(y_pred, axis=-1)
    true_positive = K.sum(K.cast((y_true == 1) & (y_pred == 1), tf.float32))
    false_negative = K.sum(K.cast((y_true == 1) & (y_pred == 0), tf.float32))
    return true_positive / (true_positive + false_negative + K.epsilon())

def jaccard_index(y_true, y_pred):
    y_pred = K.argmax(y_pred, axis=-1)
    y_true = K.cast(y_true, tf.int32)
    y_pred = K.cast(y_pred, tf.int32)
    intersection = K.sum(K.cast(y_true == y_pred, tf.float32))
    union = K.sum(K.cast(y_true, tf.float32)) + K.sum(K.cast(y_pred, tf.float32)) - intersection
    return intersection / (union + K.epsilon())

def pixel_accuracy(y_true, y_pred):
    y_pred = K.argmax(y_pred, axis=-1)
    y_true = K.cast(y_true, tf.int32)
    y_pred = K.cast(y_pred, tf.int32)
    correct_pixels = K.sum(K.cast(y_true == y_pred, tf.float32))
    total_pixels = tf.cast(tf.size(y_true), tf.float32)
    return correct_pixels / total_pixels

# Build and compile model
unet = build_unet(input_size)
unet.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss='sparse_categorical_crossentropy',
    metrics=[pixel_accuracy, dice_coefficient, precision, recall, jaccard_index]
)

# Dataset paths
train_image_path = '/content/IP-25/train_data/Images'
train_mask_path = '/content/IP-25/train_data/Labels'
val_image_path = '/content/IP-25/val_data/Images'
val_mask_path = '/content/IP-25/val_data/Labels'

train_image_list = sorted([os.path.join(train_image_path, i) for i in os.listdir(train_image_path)])
train_mask_list = sorted([os.path.join(train_mask_path, i) for i in os.listdir(train_mask_path)])
val_image_list = sorted([os.path.join(val_image_path, i) for i in os.listdir(val_image_path)])
val_mask_list = sorted([os.path.join(val_mask_path, i) for i in os.listdir(val_mask_path)])

# Data generator
def data_generator(image_list, mask_list, batch_size):
    num_samples = len(image_list)
    while True:
        indices = np.random.permutation(num_samples)
        for i in range(0, num_samples, batch_size):
            batch_indices = indices[i:i + batch_size]
            batch_images = []
            batch_masks = []

            for idx in batch_indices:
                image, mask = load_and_preprocess_image(image_list[idx], mask_list[idx])
                batch_images.append(image)
                batch_masks.append(mask)

            yield np.array(batch_images), np.array(batch_masks)

# Training setup
batch_size = 2
train_steps_per_epoch = len(train_image_list) // batch_size
val_steps_per_epoch = len(val_image_list) // batch_size

# Callbacks
callbacks = [
    tf.keras.callbacks.ModelCheckpoint('best_model2.keras', save_best_only=True, monitor='val_loss'),
    tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True),
    tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)
]

# Train the model
history = unet.fit(
    data_generator(train_image_list, train_mask_list, batch_size),
    steps_per_epoch=train_steps_per_epoch,
    epochs=10,
    validation_data=data_generator(val_image_list, val_mask_list, batch_size),
    validation_steps=val_steps_per_epoch,
    callbacks=callbacks
)

# Save the trained model
unet.save('model_image_discussion.h5')
# Out:
# Epoch 1/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 155s 878ms/step - dice_coefficient: 0.2042 - jaccard_index: 0.1164 - loss: 1.6522 - pixel_accuracy: 0.3848 - precision: 0.6306 - recall: 0.6339 - val_dice_coefficient: 0.0579 - val_jaccard_index: 0.0299 - val_loss: 27.3859 - val_pixel_accuracy: 0.1571 - val_precision: 0.0286 - val_recall: 0.0180 - learning_rate: 0.0010
# Epoch 2/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 84s 844ms/step - dice_coefficient: 0.3232 - jaccard_index: 0.1948 - loss: 1.1643 - pixel_accuracy: 0.5491 - precision: 0.7229 - recall: 0.8182 - val_dice_coefficient: 0.1090 - val_jaccard_index: 0.0581 - val_loss: 5.1411 - val_pixel_accuracy: 0.2394 - val_precision: 0.4651 - val_recall: 0.0014 - learning_rate: 0.0010
# Epoch 3/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 88s 888ms/step - dice_coefficient: 0.3548 - jaccard_index: 0.2183 - loss: 1.1021 - pixel_accuracy: 0.5798 - precision: 0.7262 - recall: 0.8272 - val_dice_coefficient: 0.1942 - val_jaccard_index: 0.1089 - val_loss: 1.9364 - val_pixel_accuracy: 0.3416 - val_precision: 0.8235 - val_recall: 0.3426 - learning_rate: 0.0010
# Epoch 4/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 84s 845ms/step - dice_coefficient: 0.3647 - jaccard_index: 0.2255 - loss: 1.0078 - pixel_accuracy: 0.6178 - precision: 0.7550 - recall: 0.8564 - val_dice_coefficient: 0.2938 - val_jaccard_index: 0.1745 - val_loss: 1.5353 - val_pixel_accuracy: 0.4491 - val_precision: 0.8146 - val_recall: 0.5531 - learning_rate: 0.0010
# Epoch 5/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 81s 817ms/step - dice_coefficient: 0.3990 - jaccard_index: 0.2524 - loss: 0.9387 - pixel_accuracy: 0.6488 - precision: 0.7898 - recall: 0.8732 - val_dice_coefficient: 0.3335 - val_jaccard_index: 0.2045 - val_loss: 1.1126 - val_pixel_accuracy: 0.5748 - val_precision: 0.8132 - val_recall: 0.8300 - learning_rate: 0.0010
# Epoch 6/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 72s 719ms/step - dice_coefficient: 0.3838 - jaccard_index: 0.2399 - loss: 0.9496 - pixel_accuracy: 0.6394 - precision: 0.7967 - recall: 0.8665 - val_dice_coefficient: 0.4026 - val_jaccard_index: 0.2554 - val_loss: 0.8771 - val_pixel_accuracy: 0.6505 - val_precision: 0.8689 - val_recall: 0.8020 - learning_rate: 0.0010
# Epoch 7/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 89s 891ms/step - dice_coefficient: 0.3866 - jaccard_index: 0.2420 - loss: 0.8843 - pixel_accuracy: 0.6604 - precision: 0.8014 - recall: 0.8736 - val_dice_coefficient: 0.4242 - val_jaccard_index: 0.2745 - val_loss: 0.8340 - val_pixel_accuracy: 0.6650 - val_precision: 0.8380 - val_recall: 0.8586 - learning_rate: 0.0010
# Epoch 8/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 77s 770ms/step - dice_coefficient: 0.4206 - jaccard_index: 0.2694 - loss: 0.8602 - pixel_accuracy: 0.6732 - precision: 0.8098 - recall: 0.8854 - val_dice_coefficient: 0.4410 - val_jaccard_index: 0.2918 - val_loss: 0.9723 - val_pixel_accuracy: 0.6273 - val_precision: 0.8185 - val_recall: 0.8406 - learning_rate: 0.0010
# Epoch 9/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 81s 810ms/step - dice_coefficient: 0.4059 - jaccard_index: 0.2575 - loss: 0.8580 - pixel_accuracy: 0.6752 - precision: 0.8250 - recall: 0.8580 - val_dice_coefficient: 0.4398 - val_jaccard_index: 0.2884 - val_loss: 0.8302 - val_pixel_accuracy: 0.6728 - val_precision: 0.8331 - val_recall: 0.8631 - learning_rate: 0.0010
# Epoch 10/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 77s 776ms/step - dice_coefficient: 0.4042 - jaccard_index: 0.2569 - loss: 0.8234 - pixel_accuracy: 0.6911 - precision: 0.8035 - recall: 0.8967 - val_dice_coefficient: 0.4078 - val_jaccard_index: 0.2607 - val_loss: 0.8444 - val_pixel_accuracy: 0.6607 - val_precision: 0.9189 - val_recall: 0.7173 - learning_rate: 0.0010
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
def build_segnet(input_shape, num_of_classes):
    inputs = Input(input_shape)

    # Encoder
    s1, p1 = encoder_block(inputs, 32)
    s2, p2 = encoder_block(p1, 64)
    s3, p3 = encoder_block(p2, 128)
    s4, p4 = encoder_block(p3, 256)

    # Bridge
    b1 = conv_block(p4, 512)

    # Decoder
    d1 = decoder_block(b1, s4, 256)
    d2 = decoder_block(d1, s3, 128)
    d3 = decoder_block(d2, s2, 64)
    d4 = decoder_block(d3, s1, 32)

    # Output layer
    outputs = Conv2D(num_of_classes, 1, padding="same", activation="softmax")(d4)

    return tf.keras.models.Model(inputs, outputs, name="SegNet")


segnet = build_segnet(input_size, num_of_classes)
segnet.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    metrics=[pixel_accuracy, jaccard_index, dice_coefficient, precision, recall]
)

# Training the model
history = segnet.fit(
    data_generator(train_image_list, train_mask_list, batch_size),
    steps_per_epoch=train_steps_per_epoch,
    epochs=10,
    validation_data=data_generator(val_image_list, val_mask_list, batch_size),
    validation_steps=val_steps_per_epoch,
    callbacks=[
        ModelCheckpoint('segnet_best_model.keras', save_best_only=True),
        EarlyStopping(patience=5, restore_best_weights=True)
    ]
)
# Out:
# Epoch 1/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 119s 902ms/step - dice_coefficient: 0.0700 - jaccard_index: 0.0368 - loss: 2.2024 - pixel_accuracy: 0.1988 - precision: 0.6226 - recall: 0.4483 - val_dice_coefficient: 0.0579 - val_jaccard_index: 0.0299 - val_loss: 3.7877 - val_pixel_accuracy: 0.1101 - val_precision: 0.3509 - val_recall: 8.8071e-04
# Epoch 2/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 84s 848ms/step - dice_coefficient: 0.2617 - jaccard_index: 0.1516 - loss: 1.4533 - pixel_accuracy: 0.5301 - precision: 0.7566 - recall: 0.8940 - val_dice_coefficient: 0.0559 - val_jaccard_index: 0.0288 - val_loss: 6.3357 - val_pixel_accuracy: 0.1100 - val_precision: 0.6996 - val_recall: 0.0781
# Epoch 3/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 85s 858ms/step - dice_coefficient: 0.3290 - jaccard_index: 0.1982 - loss: 1.2998 - pixel_accuracy: 0.5935 - precision: 0.7333 - recall: 0.8950 - val_dice_coefficient: 0.1872 - val_jaccard_index: 0.1036 - val_loss: 2.0039 - val_pixel_accuracy: 0.3389 - val_precision: 0.9203 - val_recall: 0.1627
# Epoch 4/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 85s 855ms/step - dice_coefficient: 0.3797 - jaccard_index: 0.2367 - loss: 1.1628 - pixel_accuracy: 0.6398 - precision: 0.7881 - recall: 0.8927 - val_dice_coefficient: 0.3216 - val_jaccard_index: 0.1929 - val_loss: 1.3403 - val_pixel_accuracy: 0.5604 - val_precision: 0.8574 - val_recall: 0.6638
# Epoch 5/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 81s 818ms/step - dice_coefficient: 0.3974 - jaccard_index: 0.2500 - loss: 1.0750 - pixel_accuracy: 0.6630 - precision: 0.7903 - recall: 0.8925 - val_dice_coefficient: 0.3641 - val_jaccard_index: 0.2249 - val_loss: 1.1400 - val_pixel_accuracy: 0.6173 - val_precision: 0.9058 - val_recall: 0.6597
# Epoch 6/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 72s 728ms/step - dice_coefficient: 0.3989 - jaccard_index: 0.2523 - loss: 1.0241 - pixel_accuracy: 0.6805 - precision: 0.7969 - recall: 0.9075 - val_dice_coefficient: 0.3966 - val_jaccard_index: 0.2504 - val_loss: 1.0313 - val_pixel_accuracy: 0.6627 - val_precision: 0.8798 - val_recall: 0.7657
# Epoch 7/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 80s 802ms/step - dice_coefficient: 0.4116 - jaccard_index: 0.2621 - loss: 0.9610 - pixel_accuracy: 0.6950 - precision: 0.8182 - recall: 0.9174 - val_dice_coefficient: 0.3906 - val_jaccard_index: 0.2455 - val_loss: 1.0213 - val_pixel_accuracy: 0.6525 - val_precision: 0.9253 - val_recall: 0.6904
# Epoch 8/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 81s 811ms/step - dice_coefficient: 0.4288 - jaccard_index: 0.2756 - loss: 0.9044 - pixel_accuracy: 0.7145 - precision: 0.8510 - recall: 0.9087 - val_dice_coefficient: 0.4309 - val_jaccard_index: 0.2799 - val_loss: 0.9036 - val_pixel_accuracy: 0.6939 - val_precision: 0.8582 - val_recall: 0.8805
# Epoch 9/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 79s 799ms/step - dice_coefficient: 0.4279 - jaccard_index: 0.2754 - loss: 0.8836 - pixel_accuracy: 0.7174 - precision: 0.8393 - recall: 0.9195 - val_dice_coefficient: 0.4128 - val_jaccard_index: 0.2638 - val_loss: 0.8716 - val_pixel_accuracy: 0.6989 - val_precision: 0.8716 - val_recall: 0.8624
# Epoch 10/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 78s 787ms/step - dice_coefficient: 0.4155 - jaccard_index: 0.2652 - loss: 0.8689 - pixel_accuracy: 0.7210 - precision: 0.8089 - recall: 0.9099 - val_dice_coefficient: 0.4251 - val_jaccard_index: 0.2758 - val_loss: 0.8774 - val_pixel_accuracy: 0.6917 - val_precision: 0.8431 - val_recall: 0.8735

# %%
# Save the trained model
segnet.save('segnet_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import os
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# Define color mapping for visualization
COLOR_MAPPING = {
    0: (0, 0, 0),           # Background clutter
    1: (128, 0, 0),         # Building
    2: (128, 64, 128),      # Road
    3: (0, 128, 0),         # Tree
    4: (128, 128, 0),       # Low vegetation
    5: (64, 0, 128),        # Moving car
    6: (192, 0, 192),       # Static car
    7: (64, 64, 0),         # Human
}

def class_to_rgb(predicted_mask):
    """
    Convert class indices to RGB colors based on the defined color mapping.

    Args:
        predicted_mask (np.ndarray): 2D array of class indices.

    Returns:
        np.ndarray: 3D array of RGB colors.
    """
    colorized_image = np.zeros((predicted_mask.shape[0], predicted_mask.shape[1], 3), dtype=np.uint8)
    for class_idx, color in COLOR_MAPPING.items():
        colorized_image[predicted_mask == class_idx] = color
    return colorized_image

def predict_and_visualize(image_path, model, save_path=None):
    """
    Predict the segmentation mask for a single image and visualize the result.

    Args:
        image_path (str): Path to the input image.
        model (tf.keras.Model): Trained U-Net model.
        save_path (str, optional): Path to save the visualization. If None, it only displays the result.

    Returns:
        None
    """
    # Load and preprocess the image
    image = tf.io.read_file(image_path)
    image = tf.image.decode_jpeg(image)
    image = tf.image.resize(image, [input_size[0], input_size[1]])
    image = tf.clip_by_value(image / 255.0, 0, 1)
    input_image = tf.expand_dims(image, axis=0)  # Add batch dimension

    # Predict mask
    predicted_mask = tf.argmax(model.predict(input_image), axis=-1)
    predicted_mask = tf.squeeze(predicted_mask)  # Remove batch dimension

    # Convert class mask to RGB mask
    visual_mask = class_to_rgb(predicted_mask.numpy())  # Convert to numpy for visualization

    # Plot the original image and the predicted mask
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.title("Original Image")
    plt.imshow(image)
    plt.axis('off')

    plt.subplot(1, 2, 2)
    plt.title("Predicted Mask")
    plt.imshow(visual_mask)
    plt.axis('off')

    # Save or display the visualization
    if save_path:
        # Ensure the directory exists
        save_dir = os.path.dirname(save_path)
        if not os.path.exists(save_dir):
            os.makedirs(save_dir)
        plt.savefig(save_path)
        print(f"Visualization saved to: {save_path}")
    else:
        plt.show()

# Example usage
image_path = '/content/IP-25/train_data/Images/seq10_000300.png'  # Replace with your image path
save_path = '/content/predictions/prediction.png'  # Specify a valid save directory
predict_and_visualize(image_path, segnet, save_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Visualization saved to: /content/predictions/prediction.png
